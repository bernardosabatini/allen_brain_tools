# %% [markdown]
# # Initialize and find the ImageDataSet ids for the genes of interest

# %%
import requests
import json

#Best section for cm from the Met coronal dataset
#http://mouse.brain-map.org/experiment/siv?id=79591401&imageId=79603932&initImage=ish&coordSystem=pixel&x=4804&y=2733&z=5
    
genes=['Met', 'Utrn', 'Calcr', 'Unc5c', 'Nr2f2', 'Elmo1', 'Pcp4l1', 'Pde4b', 'Chrm2', 'Cbln2', 'Tacr3', 'Galnt18', 'Wscd1','Rxfp1']
#genes=['Arhgap36','Asb4','Hs3st4'  ,'Prkcq','St8sia2','Trh','Igsf1','Pax5','Prmt8','Prph','Fam19a2','Clic1','Fstl5','Adra2a','Slc6a1','Tmem176b']
#genes=['Adora2a', 'Tph2', 'Slc17a7']
section_orientation='coronal'

imageDataSet_ids={}
imageDataSet_ids_str=[]

for gene in genes:
    urlString=''.join(['http://api.brain-map.org/api/v2/data/',
                      'query.json?criteria=model::SectionDataSet,',
                      'rma::criteria,',
                      "[failed$eq'false'],",
                      "products[abbreviation$eq'Mouse'],",
                      "plane_of_section[name$eq'",
                      section_orientation,
                      "'],",
                      "genes[acronym$eq'",
                        gene,
                        "']"])
    print(gene)
    response = requests.get(urlString)
    rJson=response.json()
 #   print(rJson)
    msg=rJson['msg']
    if not msg:
        id=0;
    else:
        id=rJson['msg'][0]['id'];
    imageDataSet_ids[gene]=id
    imageDataSet_ids_str=imageDataSet_ids_str+[str(id)]
    
    
imageDataSet_ids
# Out:
# Met
# Utrn
# Calcr
# Unc5c
# Nr2f2
# Elmo1
# Pcp4l1
# Pde4b
# Chrm2
# Cbln2
# Tacr3
# Galnt18
# Wscd1
# Rxfp1
# {'Calcr': 75080999,
#  'Cbln2': 70231306,
#  'Chrm2': 70560343,
#  'Elmo1': 70743907,
#  'Galnt18': 70928328,
#  'Met': 79591401,
#  'Nr2f2': 112646890,
#  'Pcp4l1': 75084520,
#  'Pde4b': 2472,
#  'Rxfp1': 70562124,
#  'Tacr3': 1297,
#  'Unc5c': 71670708,
#  'Utrn': 73929872,
#  'Wscd1': 71920517}

# %%
def getGeneID(gene):
    section_orientation='coronal'
    urlString=''.join(['http://api.brain-map.org/api/v2/data/',
            'query.json?criteria=model::SectionDataSet,',
            'rma::criteria,',
            "[failed$eq'false'],",
            "products[abbreviation$eq'Mouse'],",
            "plane_of_section[name$eq'",
            section_orientation,
            "'],",
            "genes[acronym$eq'",
            gene,
            "']"])
    response = requests.get(urlString)
    rJson=response.json()
    msg=rJson['msg']
    if not msg:
        id=0;
    else:
        id=rJson['msg'][0]['id'];
    return id

# %% [markdown]
# # Get the reference image and plot it

# %%
import io
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def getImage(image_id, downSample, display, allChan):
    urlString=''.join(["http://api.brain-map.org/api/v2/image_download/",
                                    str(image_id),
                                    "?",
                         #           "view=expression&",
                                     "downsample=",
                                     str(downSample)])
    print(urlString)
    response = requests.get(urlString)

    response.raise_for_status()
    with io.BytesIO(response.content) as f:
        with Image.open(f) as img:
            newImage=np.array(img)
    if allChan==False:
        newImage=newImage[:,:,0]
    if (display==1):
        fig = plt.figure()
        ax = fig.add_subplot(1,1,1)
        if allChan==False:
            ax.imshow(newImage, cmap='gray')
        else:
            ax.imshow(newImage)            
        plt.show()        
        
    return newImage

# %%
zeroImage_id=79603932
zeroDataSet_id=79591401

downSample=1;
zeroImage=getImage(zeroImage_id, downSample, 1, False)
# Out:
# http://api.brain-map.org/api/v2/image_download/79603932?downsample=1

# %%
from skimage import dtype_limits
plt_img = zeroImage[1200:2000,2000:2750,0]
#img = dtype_limits(plt_img)[1] - plt_img
img=plt_img
img.shape
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# ### Get center pixel

# %%
zeroImageSize=zeroImage.shape
#xC=round(zeroImageSize[1]/2)
#yC=round(zeroImageSize[0]/2)
xC=2375
yC=1600
xC_raw=xC*(downSample+1)
yC_raw=yC*(downSample+1)

dX=200
dY=400
L=(downSample+1)*(xC-dX)
R=(downSample+1)*(xC+dX)
U=(downSample+1)*(yC-dY)
D=(downSample+1)*(yC+dY)

allX=[L, R, R, L]
allY=[U, U, D, D]

# %% [markdown]
# ### Try to go straight from each of the image ROI corners to coordinates and slices in all the other data sets

# %%
imageDataSet_ids[genes]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-274-5656fd6ec3bd> in <module>()
# ----> 1 imageDataSet_ids[genes]
#
# TypeError: unhashable type: 'list'

# %%
# Out:
# '79591401,73929872,75080999,71670708,112646890,70743907,75084520,2472,70560343,70231306,1297,70928328,71920517,70562124'

# %%
returns=[]

for xy in zip(allX, allY):
    urlString=''.join(["http://api.brain-map.org/api/v2/image_to_image/",
                                    str(zeroImage_id),
                                    ".json?",
                                    "x=",
                                    str(xy[0]),
                                    "&y=",
                                    str(xy[1]), 
                                    "&section_data_set_ids=",
                                    ','.join(imageDataSet_ids_str)
                                    ])        
    print(urlString)
    response = requests.get(urlString)
    reference_equiv=response.json()
#    print(reference_equiv)
    returns=returns+[reference_equiv]
#http://api.brain-map.org/api/v2/image_to_image/68173101.xml?x=6208&y=2368&section_data_set_ids=67810540,69782969
# Out:
# http://api.brain-map.org/api/v2/image_to_image/79603932.json?x=4350&y=2400&section_data_set_ids=79591401,73929872,75080999,71670708,112646890,70743907,75084520,2472,70560343,70231306,1297,70928328,71920517,70562124
# http://api.brain-map.org/api/v2/image_to_image/79603932.json?x=5150&y=2400&section_data_set_ids=79591401,73929872,75080999,71670708,112646890,70743907,75084520,2472,70560343,70231306,1297,70928328,71920517,70562124
# http://api.brain-map.org/api/v2/image_to_image/79603932.json?x=5150&y=4000&section_data_set_ids=79591401,73929872,75080999,71670708,112646890,70743907,75084520,2472,70560343,70231306,1297,70928328,71920517,70562124
# http://api.brain-map.org/api/v2/image_to_image/79603932.json?x=4350&y=4000&section_data_set_ids=79591401,73929872,75080999,71670708,112646890,70743907,75084520,2472,70560343,70231306,1297,70928328,71920517,70562124

# %%
returns[1]['msg'][0]['image_sync']['section_number']
xys=np.zeros((3,4))

# %%
image_id_list=[]
xy_list=[]

for c in range(0,len(returns[0]['msg'])):
    image_id=returns[0]['msg'][c]['image_sync']['section_image_id']
    
    xys=np.zeros((3,4))
    xy_list_this=[]
    
    use=True
    for p in range(0,4):
  #      print(returns[p]['msg'][c]['image_sync']['section_data_set_id'])
        xys[0,p]=returns[p]['msg'][c]['image_sync']['x']
        xys[1,p]=returns[p]['msg'][c]['image_sync']['y']
        xys[2,p]=returns[p]['msg'][c]['image_sync']['section_number']

        if image_id!=returns[p]['msg'][c]['image_sync']['section_image_id']:
            use=False
        xy_list_this
        xy_list_this=xy_list_this+[(round(xys[0,p]), round(xys[1,p]))]

    if use==True:
        image_id_list=image_id_list+[image_id]
        xy_list=xy_list+[xy_list_this]
        print('using')
     #   print(xys)
    else:
        print(image_id, 'does not have slice constancy.  Must be tilted.  Skipping')
    #    print(xys)
# Out:
# using
# using
# using
# using
# 112647002 does not have slice constancy.  Must be tilted.  Skipping
# 70611701 does not have slice constancy.  Must be tilted.  Skipping
# using
# using
# using
# using
# using
# using
# 71755781 does not have slice constancy.  Must be tilted.  Skipping
# 70469502 does not have slice constancy.  Must be tilted.  Skipping

# %%
for c in range(0, len(image_id_list)):
    print(image_id_list[c])
    print(xy_list[c])
# Out:
# 79603932
# [(4350.0, 2400.0), (5150.0, 2400.0), (5150.0, 4000.0), (4350.0, 4000.0)]
# 73892839
# [(3979.0, 4138.0), (4756.0, 4200.0), (4637.0, 5800.0), (3860.0, 5737.0)]
# 75034495
# [(4071.0, 2588.0), (4873.0, 2600.0), (4843.0, 4219.0), (4041.0, 4206.0)]
# 71501901
# [(3944.0, 2614.0), (4803.0, 2632.0), (4763.0, 4114.0), (3905.0, 4096.0)]
# 75017436
# [(4136.0, 2844.0), (4906.0, 2934.0), (4721.0, 4597.0), (3950.0, 4506.0)]
# 101360522
# [(3429.0, 2307.0), (3917.0, 2353.0), (3842.0, 3459.0), (3353.0, 3414.0)]
# 70383547
# [(3070.0, 2706.0), (3919.0, 2769.0), (3796.0, 4414.0), (2947.0, 4351.0)]
# 69908605
# [(3522.0, 2648.0), (4372.0, 2644.0), (4379.0, 4226.0), (3529.0, 4231.0)]
# 101354544
# [(2147.0, 1906.0), (2701.0, 1947.0), (2624.0, 3134.0), (2071.0, 3093.0)]
# 70846634
# [(4236.0, 2668.0), (5090.0, 2753.0), (4925.0, 4206.0), (4071.0, 4121.0)]

# %%
# Out:
# array([[ 3830.39913745,  4670.65894712,  4819.5800975 ,  3979.40923358],
#        [ 2273.97475337,  2330.22573461,  4495.49987427,  4437.9420486 ],
#        [  124.        ,   124.        ,   128.        ,   128.        ]])

# %% [markdown]
# # Find the x,y,z anatomoical coordinate in the reference atlas that matches with the choosen point (center) in the zeroImage
# This is go from an (x,y) in a image to the (x,y,z) coordinate in a reference dataset
# The plan will be to do this for each of N images that span the structure of interest, the (x,y) set to the center of the image

# %%
import sys
sys.path
sys.path.insert(0, "/Users/bernardosabatini/Documents/GitHub/ecallen")
from ecallen import images as ecimg


pir_from_ecallen = ecimg.xy_to_pir(allX,
                                   allY,
                                   zeroDataSet_id,
                                   zeroImage_id
                                   )
pir_from_ecallen
# Out:
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionImage,rma::criteria,[id$eq79603932],rma::include,alignment2d
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,[id$eq79591401],rma::include,alignment3d
# array([[ 10211.57204123,  10233.92044456,  10211.05261543,  10188.7042121 ],
#        [  3492.10076247,   3541.77295587,   5302.51020084,   5252.83800744],
#        [  5288.96436221,   6215.34887638,   6117.24849937,   5190.8639852 ]])

# %%
pir_from_ecallen.shape[1]
# Out:
# 4

# %%
urlString="".join(["http://api.brain-map.org/api/v2/image_to_reference/",
                                str(zeroImage_id),
                                ".json?x=",
                                str(xC_raw),
                                "&y=",
                                str(yC_raw)])
print(urlString)
response = requests.get(urlString)

print(response)
reference_equiv=response.json();
reference_equiv
# Out:
# http://api.brain-map.org/api/v2/image_to_reference/79603932.json?x=4750&y=3200
# <Response [200]>
# {'id': 0,
#  'msg': {'image_to_reference': {'x': 10211.31232832981,
#    'y': 4397.305481655492,
#    'z': 5703.10643079128}},
#  'num_rows': 0,
#  'start_row': 0,
#  'success': True,
#  'total_rows': 0}

# %%
returns
# Out:
# [{'id': 0,
#   'msg': [{'image_sync': {'section_data_set_id': '79591401',
#      'section_image_id': 79603932,
#      'section_number': 133,
#      'x': 4350.03444602221,
#      'y': 2400.0174768163124}},
#    {'image_sync': {'section_data_set_id': '73929872',
#      'section_image_id': 73892839,
#      'section_number': 133,
#      'x': 3979.451974773331,
#      'y': 4137.544431408096}},
#    {'image_sync': {'section_data_set_id': '75080999',
#      'section_image_id': 75034495,
#      'section_number': 132,
#      'x': 4070.6873564016882,
#      'y': 2587.8229331637513}},
#    {'image_sync': {'section_data_set_id': '71670708',
#      'section_image_id': 71501901,
#      'section_number': 140,
#      'x': 3944.3257909670574,
#      'y': 2613.719460267596}},
#    {'image_sync': {'section_data_set_id': '112646890',
#      'section_image_id': 112647002,
#      'section_number': 130,
#      'x': 3966.5629877712554,
#      'y': 2911.4013829319915}},
#    {'image_sync': {'section_data_set_id': '70743907',
#      'section_image_id': 70611701,
#      'section_number': 121,
#      'x': 4227.909342751699,
#      'y': 2672.3962101252228}},
#    {'image_sync': {'section_data_set_id': '75084520',
#      'section_image_id': 75017436,
#      'section_number': 132,
#      'x': 4135.827181036593,
#      'y': 2843.622723376038}},
#    {'image_sync': {'section_data_set_id': '2472',
#      'section_image_id': 101360522,
#      'section_number': 132,
#      'x': 3428.5667669556265,
#      'y': 2307.3228901559023}},
#    {'image_sync': {'section_data_set_id': '70560343',
#      'section_image_id': 70383547,
#      'section_number': 126,
#      'x': 3070.431560045275,
#      'y': 2705.598168972331}},
#    {'image_sync': {'section_data_set_id': '70231306',
#      'section_image_id': 69908605,
#      'section_number': 124,
#      'x': 3522.4539193088444,
#      'y': 2648.4131594836927}},
#    {'image_sync': {'section_data_set_id': '1297',
#      'section_image_id': 101354544,
#      'section_number': 102,
#      'x': 2146.9764947897247,
#      'y': 1906.196092301244}},
#    {'image_sync': {'section_data_set_id': '70928328',
#      'section_image_id': 70846634,
#      'section_number': 108,
#      'x': 4236.0425986511045,
#      'y': 2667.8584788191565}},
#    {'image_sync': {'section_data_set_id': '71920517',
#      'section_image_id': 71755781,
#      'section_number': 132,
#      'x': 3705.1105254543977,
#      'y': 2941.3579108972526}},
#    {'image_sync': {'section_data_set_id': '70562124',
#      'section_image_id': 70469502,
#      'section_number': 124,
#      'x': 3830.399137448342,
#      'y': 2273.974753366892}}],
#   'success': True},
#  {'id': 0,
#   'msg': [{'image_sync': {'section_data_set_id': '79591401',
#      'section_image_id': 79603932,
#      'section_number': 133,
#      'x': 5150.039528901939,
#      'y': 2400.0172759121906}},
#    {'image_sync': {'section_data_set_id': '73929872',
#      'section_image_id': 73892839,
#      'section_number': 133,
#      'x': 4755.779854355915,
#      'y': 4200.433444743844}},
#    {'image_sync': {'section_data_set_id': '75080999',
#      'section_image_id': 75034495,
#      'section_number': 132,
#      'x': 4872.741553114378,
#      'y': 2600.4853490317255}},
#    {'image_sync': {'section_data_set_id': '71670708',
#      'section_image_id': 71501901,
#      'section_number': 140,
#      'x': 4802.963447818957,
#      'y': 2631.723106994947}},
#    {'image_sync': {'section_data_set_id': '112646890',
#      'section_image_id': 112647018,
#      'section_number': 122,
#      'x': 4415.269831645475,
#      'y': 2662.81530954159}},
#    {'image_sync': {'section_data_set_id': '70743907',
#      'section_image_id': 70612303,
#      'section_number': 117,
#      'x': 4371.064710439632,
#      'y': 2221.0023721767684}},
#    {'image_sync': {'section_data_set_id': '75084520',
#      'section_image_id': 75017436,
#      'section_number': 132,
#      'x': 4906.326510479907,
#      'y': 2934.0201237286497}},
#    {'image_sync': {'section_data_set_id': '2472',
#      'section_image_id': 101360522,
#      'section_number': 132,
#      'x': 3917.2924483570832,
#      'y': 2352.627729022993}},
#    {'image_sync': {'section_data_set_id': '70560343',
#      'section_image_id': 70383547,
#      'section_number': 126,
#      'x': 3918.997499222183,
#      'y': 2769.245666841185}},
#    {'image_sync': {'section_data_set_id': '70231306',
#      'section_image_id': 69908605,
#      'section_number': 124,
#      'x': 4371.94898126035,
#      'y': 2643.5863194683725}},
#    {'image_sync': {'section_data_set_id': '1297',
#      'section_image_id': 101354544,
#      'section_number': 102,
#      'x': 2700.8788815009693,
#      'y': 1946.8377205725844}},
#    {'image_sync': {'section_data_set_id': '70928328',
#      'section_image_id': 70846634,
#      'section_number': 108,
#      'x': 5089.785847059358,
#      'y': 2753.303189785781}},
#    {'image_sync': {'section_data_set_id': '71920517',
#      'section_image_id': 71755777,
#      'section_number': 124,
#      'x': 4685.407336756025,
#      'y': 2456.1746789334725}},
#    {'image_sync': {'section_data_set_id': '70562124',
#      'section_image_id': 70469502,
#      'section_number': 124,
#      'x': 4670.658947117913,
#      'y': 2330.225734613801}}],
#   'success': True},
#  {'id': 0,
#   'msg': [{'image_sync': {'section_data_set_id': '79591401',
#      'section_image_id': 79603932,
#      'section_number': 133,
#      'x': 5150.039818430797,
#      'y': 4000.026957840055}},
#    {'image_sync': {'section_data_set_id': '73929872',
#      'section_image_id': 73892839,
#      'section_number': 133,
#      'x': 4636.501145732837,
#      'y': 5799.720308807946}},
#    {'image_sync': {'section_data_set_id': '75080999',
#      'section_image_id': 75034495,
#      'section_number': 132,
#      'x': 4843.3084642751255,
#      'y': 4218.87091549843}},
#    {'image_sync': {'section_data_set_id': '71670708',
#      'section_image_id': 71501901,
#      'section_number': 140,
#      'x': 4763.205600911775,
#      'y': 4114.267201531678}},
#    {'image_sync': {'section_data_set_id': '112646890',
#      'section_image_id': 112647018,
#      'section_number': 122,
#      'x': 4339.833266080758,
#      'y': 4374.449170852082}},
#    {'image_sync': {'section_data_set_id': '70743907',
#      'section_image_id': 70612303,
#      'section_number': 117,
#      'x': 4208.832931690769,
#      'y': 3791.3766504832693}},
#    {'image_sync': {'section_data_set_id': '75084520',
#      'section_image_id': 75017436,
#      'section_number': 132,
#      'x': 4720.981227135652,
#      'y': 4596.820360869266}},
#    {'image_sync': {'section_data_set_id': '2472',
#      'section_image_id': 101360522,
#      'section_number': 132,
#      'x': 3841.6018793664625,
#      'y': 3459.2856675231146}},
#    {'image_sync': {'section_data_set_id': '70560343',
#      'section_image_id': 70383547,
#      'section_number': 126,
#      'x': 3795.696701862415,
#      'y': 4414.181470465045}},
#    {'image_sync': {'section_data_set_id': '70231306',
#      'section_image_id': 69908605,
#      'section_number': 124,
#      'x': 4378.884436882379,
#      'y': 4226.205251573237}},
#    {'image_sync': {'section_data_set_id': '1297',
#      'section_image_id': 101354544,
#      'section_number': 102,
#      'x': 2624.4423749994676,
#      'y': 3133.898578093749}},
#    {'image_sync': {'section_data_set_id': '70928328',
#      'section_image_id': 70846634,
#      'section_number': 108,
#      'x': 4924.615800922187,
#      'y': 4206.173872823337}},
#    {'image_sync': {'section_data_set_id': '71920517',
#      'section_image_id': 71755781,
#      'section_number': 132,
#      'x': 4560.33779839843,
#      'y': 4603.661875272613}},
#    {'image_sync': {'section_data_set_id': '70562124',
#      'section_image_id': 70468902,
#      'section_number': 128,
#      'x': 4819.580097501189,
#      'y': 4495.499874268834}}],
#   'success': True},
#  {'id': 0,
#   'msg': [{'image_sync': {'section_data_set_id': '79591401',
#      'section_image_id': 79603932,
#      'section_number': 133,
#      'x': 4350.034735551067,
#      'y': 4000.0271587441766}},
#    {'image_sync': {'section_data_set_id': '73929872',
#      'section_image_id': 73892839,
#      'section_number': 133,
#      'x': 3860.1732661502547,
#      'y': 5736.8312954722}},
#    {'image_sync': {'section_data_set_id': '75080999',
#      'section_image_id': 75034495,
#      'section_number': 132,
#      'x': 4041.254267562434,
#      'y': 4206.208499630456}},
#    {'image_sync': {'section_data_set_id': '71670708',
#      'section_image_id': 71501901,
#      'section_number': 140,
#      'x': 3904.567944059875,
#      'y': 4096.263554804327}},
#    {'image_sync': {'section_data_set_id': '112646890',
#      'section_image_id': 112647002,
#      'section_number': 130,
#      'x': 3912.7198747170423,
#      'y': 4623.856290014221}},
#    {'image_sync': {'section_data_set_id': '70743907',
#      'section_image_id': 70611701,
#      'section_number': 121,
#      'x': 4084.627232469299,
#      'y': 4244.612826328894}},
#    {'image_sync': {'section_data_set_id': '75084520',
#      'section_image_id': 75017436,
#      'section_number': 132,
#      'x': 3950.4818976923398,
#      'y': 4506.422960516655}},
#    {'image_sync': {'section_data_set_id': '2472',
#      'section_image_id': 101360522,
#      'section_number': 132,
#      'x': 3352.876197965006,
#      'y': 3413.980828656025}},
#    {'image_sync': {'section_data_set_id': '70560343',
#      'section_image_id': 70383547,
#      'section_number': 126,
#      'x': 2947.1307626855064,
#      'y': 4350.53397259619}},
#    {'image_sync': {'section_data_set_id': '70231306',
#      'section_image_id': 69908605,
#      'section_number': 124,
#      'x': 3529.3893749308722,
#      'y': 4231.032091588557}},
#    {'image_sync': {'section_data_set_id': '1297',
#      'section_image_id': 101354544,
#      'section_number': 102,
#      'x': 2070.539988288222,
#      'y': 3093.25694982241}},
#    {'image_sync': {'section_data_set_id': '70928328',
#      'section_image_id': 70846634,
#      'section_number': 108,
#      'x': 4070.8725525139334,
#      'y': 4120.729161856713}},
#    {'image_sync': {'section_data_set_id': '71920517',
#      'section_image_id': 71755781,
#      'section_number': 132,
#      'x': 3714.7542664553444,
#      'y': 4609.070418476868}},
#    {'image_sync': {'section_data_set_id': '70562124',
#      'section_image_id': 70468902,
#      'section_number': 128,
#      'x': 3979.409233575393,
#      'y': 4437.942048598181}}],
#   'success': True}]

# %%
import numpy as np
from scipy import ndimage
import matplotlib as mpl
import matplotlib.pyplot as plt

def plotWithPoints(p, image_id):
    mpl.rcParams.update({'image.cmap': 'gray',
                         'lines.markersize': 12,
                         'axes.prop_cycle': mpl.cycler('color', ['#00ff00'])})


    gImage=getImage(image_id, downSample, 0, False)

    plt.imshow(gImage, cmap='gray')
    for xy in p:
        plt.plot(xy[0], xy[1], '.')
    plt.axis('image')
    plt.show()

# %%
p = [(L/(downSample+1), U/(downSample+1)), 
     (R/(downSample+1), U/(downSample+1)),
     (L/(downSample+1), D/(downSample+1)), 
     (R/(downSample+1), D/(downSample+1))]
     
plotWithPoints(p, 79603932)
# Out:
# http://api.brain-map.org/api/v2/image_download/79603932?downsample=1

# %% [markdown]
# ## Get the x,y,z (now true anatomical coordinates) of the corresponding point in the reference atlas.

# %%
zeroImageToReference_xyz=reference_equiv['msg']['image_to_reference']
print (zeroImageToReference_xyz)
print(zeroImageToReference_xyz['x'])
# Out:
# {'x': 10211.31232832981, 'y': 4397.305481655492, 'z': 5703.10643079128}
# 10211.31232832981

# %% [markdown]
# ## Get the sections number and coordinates within each image set of each Gene that best matches with the x,y,z coordinate of the reference atlas

# %%
matchingJson={}

for gene in genes:
    print(gene)
    for c in range(0,pir_from_ecallen.shape[1]-1):
        print(pir_from_ecallen[0,c], pir_from_ecallen[1,c], pir_from_ecallen[2,c])
        
        
        
    urlString=''.join(['http://api.brain-map.org/api/v2/reference_to_image/10.json?',
                        'x=',
                        str(round(zeroImageToReference_xyz['x'])),
                        '&y=',
                        str(round(zeroImageToReference_xyz['y'])),
                        '&z=',
                        str(round(zeroImageToReference_xyz['z'])),
                        "&section_data_set_ids=",
                        str(imageDataSet_ids[gene])])
 #   print(urlString)
    response = requests.get(urlString)
    rJson=response.json()
    matchingJson[gene]=rJson
#    print(rJson)
    print()
    print(gene)
#    print(rJson['msg'][0]['image_sync'])
    print(rJson['msg'][0]['image_sync']['section_number'])
    print(rJson['msg'][0]['image_sync']['section_image_id'])
    print(rJson['msg'][0]['image_sync']['x'])
    print(rJson['msg'][0]['image_sync']['y'])
# Out:
# Met
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Met
# 133
# 79603932
# 4701.737325439709
# 3202.4553066960143
# Utrn
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Utrn
# 133
# 73892839
# 4260.90492114905
# 4967.28152577588
# Calcr
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Calcr
# 132
# 75034495
# 4408.504445797036
# 3405.054524464367
# Unc5c
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Unc5c
# 140
# 71501901
# 4301.808463323618
# 3365.202371778975
# Nr2f2
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Nr2f2
# 130
# 112647002
# 4317.963532245948
# 3782.1572077733967
# Elmo1
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Elmo1
# 121
# 70611701
# 4519.956595768383
# 3493.174550632909
# Pcp4l1
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Pcp4l1
# 132
# 75017436
# 4381.571370604546
# 3717.30558996177
# Pde4b
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Pde4b
# 132
# 101360522
# 3605.4821072986697
# 2882.296438316785
# Chrm2
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Chrm2
# 126
# 70383547
# 3381.623694163554
# 3558.557844003978
# Cbln2
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Cbln2
# 124
# 69908605
# 3899.362749262958
# 3440.0297413350545
# Tacr3
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Tacr3
# 102
# 101354544
# 2352.135151566562
# 2519.409296589851
# Galnt18
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Galnt18
# 108
# 70846634
# 4528.523446182642
# 3434.077351173355
# Wscd1
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Wscd1
# 132
# 71755781
# 4081.658130079
# 3775.390097506308
# Rxfp1
# 10211.5720412 3492.10076247 5288.96436221
# 10233.9204446 3541.77295587 6215.34887638
# 10211.0526154 5302.51020084 6117.24849937
#
# Rxfp1
# 128
# 70468902
# 4404.926917098255
# 3665.348678684715

# %%
matchingJson={}

for gene in genes:
    urlString=''.join(['http://api.brain-map.org/api/v2/reference_to_image/10.json?',
                        'x=',
                        str(round(zeroImageToReference_xyz['x'])),
                        '&y=',
                        str(round(zeroImageToReference_xyz['y'])),
                        '&z=',
                        str(round(zeroImageToReference_xyz['z'])),
                        "&section_data_set_ids=",
                        str(imageDataSet_ids[gene])])
 #   print(urlString)
    response = requests.get(urlString)
    rJson=response.json()
    matchingJson[gene]=rJson
#    print(rJson)
    print()
    print(gene)
#    print(rJson['msg'][0]['image_sync'])
    print(rJson['msg'][0]['image_sync']['section_number'])
    print(rJson['msg'][0]['image_sync']['section_image_id'])
    print(rJson['msg'][0]['image_sync']['x'])
    print(rJson['msg'][0]['image_sync']['y'])
# Out:
# Met
# 133
# 79603932
# 4701.737325439709
# 3202.4553066960143
#
# Utrn
# 133
# 73892839
# 4260.90492114905
# 4967.28152577588
#
# Calcr
# 132
# 75034495
# 4408.504445797036
# 3405.054524464367
#
# Unc5c
# 140
# 71501901
# 4301.808463323618
# 3365.202371778975
#
# Nr2f2
# 130
# 112647002
# 4317.963532245948
# 3782.1572077733967
#
# Elmo1
# 121
# 70611701
# 4519.956595768383
# 3493.174550632909
#
# Pcp4l1
# 132
# 75017436
# 4381.571370604546
# 3717.30558996177
#
# Pde4b
# 132
# 101360522
# 3605.4821072986697
# 2882.296438316785
#
# Chrm2
# 126
# 70383547
# 3381.623694163554
# 3558.557844003978
#
# Cbln2
# 124
# 69908605
# 3899.362749262958
# 3440.0297413350545
#
# Tacr3
# 102
# 101354544
# 2352.135151566562
# 2519.409296589851
#
# Galnt18
# 108
# 70846634
# 4528.523446182642
# 3434.077351173355
#
# Wscd1
# 132
# 71755781
# 4081.658130079
# 3775.390097506308
#
# Rxfp1
# 128
# 70468902
# 4404.926917098255
# 3665.348678684715

# %%
matchingImages={}
for gene in genes:
    matchID=matchingJson[gene]['msg'][0]['image_sync']['section_image_id']
    print(gene, matchID)
    matchingImages[gene]=getImage(matchID, 3, 1)
    print(matchingImages[gene].shape)
    print()
# Out:
# Met 79603932
# http://api.brain-map.org/api/v2/image_download/79603932?downsample=3
# (780, 1128, 3)
#
# Utrn 73892839
# http://api.brain-map.org/api/v2/image_download/73892839?downsample=3
# (962, 1386, 3)
#
# Calcr 75034495
# http://api.brain-map.org/api/v2/image_download/75034495?downsample=3
# (818, 1108, 3)
#
# Unc5c 71501901
# http://api.brain-map.org/api/v2/image_download/71501901?downsample=3
# (820, 1076, 3)
#
# Nr2f2 112647002
# http://api.brain-map.org/api/v2/image_download/112647002?downsample=3
# (872, 1016, 3)
#
# Elmo1 70611701
# http://api.brain-map.org/api/v2/image_download/70611701?downsample=3
# (856, 1136, 3)
#
# Pcp4l1 75017436
# http://api.brain-map.org/api/v2/image_download/75017436?downsample=3
# (838, 1114, 3)
#
# Pde4b 101360522
# http://api.brain-map.org/api/v2/image_download/101360522?downsample=3
# (687, 841, 3)
#
# Chrm2 70383547
# http://api.brain-map.org/api/v2/image_download/70383547?downsample=3
# (838, 886, 3)
#
# Cbln2 69908605
# http://api.brain-map.org/api/v2/image_download/69908605?downsample=3
# (814, 1078, 3)
#
# Tacr3 101354544
# http://api.brain-map.org/api/v2/image_download/101354544?downsample=3
# (530, 655, 3)
#
# Galnt18 70846634
# http://api.brain-map.org/api/v2/image_download/70846634?downsample=3
# (826, 1124, 3)
#
# Wscd1 71755781
# http://api.brain-map.org/api/v2/image_download/71755781?downsample=3
# (876, 1074, 3)
#
# Rxfp1 70468902
# http://api.brain-map.org/api/v2/image_download/70468902?downsample=3
# (1018, 1042, 3)

# %%
response = requests.get("http://api.brain-map.org/api/v2/structure_graph_download/1.json")

# %%
for gene in genes:
    if imageDataSet_ids[gene]>0:
        build_string=''.join(['http://api.brain-map.org/api/v2/data/',
                      'query.json?criteria=model::SectionDataSet,',
                      'rma::criteria,',
                      "[failed$eq'false'],",
                      "products[abbreviation$eq'Mouse'],",
                      "plane_of_section[name$eq'",
                      section_orientation,
                      "'],",
                      "genes[acronym$eq'",
                        gene,
                        "']"])
        print(build_string)
        response = requests.get(build_string)
        rJson=response.json()
        imageDataSet_ids[gene]=rJson['msg'][0]['specimen_id']


response = requests.get("http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,[failed$eq'false'],products[abbreviation$eq'Mouse'],plane_of_section[name$eq'sagittal'],genes[acronym$eq'Adora2a']")
# Out:
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,[failed$eq'false'],products[abbreviation$eq'Mouse'],plane_of_section[name$eq'coronal'],genes[acronym$eq'Adora2a']
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,[failed$eq'false'],products[abbreviation$eq'Mouse'],plane_of_section[name$eq'coronal'],genes[acronym$eq'Tph2']
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,[failed$eq'false'],products[abbreviation$eq'Mouse'],plane_of_section[name$eq'coronal'],genes[acronym$eq'Slc17a7']

# %%
jj=response.json();
jj['msg'][0]['specimen_id']
# Out:
# 69434237

# %%
''.join(['a', str(3)])
# Out:
# 'a3'

# %%
for gene in genes:
    if imageDataSet_ids[gene]>0:
        newName=''.join([str(imageDataSet_ids[gene]), '.zip'])
        print(newName)
        build_string=''.join(['http://api.brain-map.org/',
                    'grid_data/download/',
                    str(imageDataSet_ids[gene]),
                    '?include=energy'])
        req=requests.get(build_string, stream=True)
        req.raise_for_status()
        with open(newName, 'wb') as fd:
            for chunk in req.iter_content(chunk_size=50000):
#                    print('Received a Chunk')
                fd.write(chunk)
# Out:
# 71358591.zip
# 71670693.zip
# 77925023.zip
# 71016631.zip
# 70232000.zip
# 73636033.zip
# 67809267.zip
# 72283812.zip
# 73615550.zip
# 476.zip
# 77866852.zip

# %%
import zipfile
pp=zipfile.ZipFile('test.zip')
print("try")
pp.namelist()
rrr=pp.read('energy.raw')
#pp.extractall()
# Out:
# try

# %%
import sys 
sys.getsizeof(rrr)
# Out:
# 637337

# %%
print(req.headers)
# Out:
# {'Date': 'Thu, 28 Sep 2017 20:59:09 GMT', 'Server': 'Apache', 'Cache-Control': 'private', 'Access-Control-Allow-Origin': '*', 'Access-Control-Max-Age': '1728000', 'X-Request-Id': 'eb829f216bcc870df5386705e430e2bb', 'Content-Disposition': 'attachment; filename=Adora2a_P56_coronal_72109410_200um.zip', 'Access-Control-Allow-Methods': 'POST, GET, OPTIONS', 'Content-Transfer-Encoding': 'binary', 'X-UA-Compatible': 'IE=Edge,chrome=1', 'ETag': '"e0d0b058fd3fef1250bf0b706e1e700c"', 'X-Runtime': '0.739844', 'X-Rack-Cache': 'miss', 'Status': '200 OK', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Keep-Alive': 'timeout=15, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/octet-stream', 'Set-Cookie': 'BIGipServerApi_pool=2250852106.20480.0000; path=/'}

# %%
print(req.encoding)
# Out:
# None

# %% [markdown]
# # Different approach
# Start with the csv file from KW
# Read it in and store the informaiton in geneData
# The first 6 columns are the ones from KW.  The 7th is the imageSetID for that gene coronal data

# %%
import csv

with open('cm.csv', newline='') as myFile:  
    reader = csv.reader(myFile)
    rownum=0
    for row in reader:
        if rownum==0:
            geneData=[row+['id']]
            rownum=1;
        else:
            gene=row[0]
            id=getGeneID(gene)
            if id==0:
                print('for gene', gene, 'there is no coronal data.  Skipping')
            else:
                print('for gene', gene, 'coronal data has id', str(id))
                geneData=geneData+[row+[id]]
                rownum=rownum+1
# Out:
# for gene Arhgap36 there is no coronal data.  Skipping
# for gene Asb4 coronal data has id 71358591
# for gene Hs3st4 there is no coronal data.  Skipping
# for gene Prkcq coronal data has id 71670693
# for gene St8sia2 coronal data has id 77925023
# for gene Trh coronal data has id 71016631
# for gene Igsf1 there is no coronal data.  Skipping
# for gene Pax5 there is no coronal data.  Skipping
# for gene Prmt8 there is no coronal data.  Skipping
# for gene Prph coronal data has id 70232000
# for gene Fam19a2 coronal data has id 73636033
# for gene Clic1 coronal data has id 67809267
# for gene Fstl5 coronal data has id 72283812
# for gene Adra2a coronal data has id 73615550
# for gene Slc6a1 coronal data has id 476
# for gene Tmem176b coronal data has id 77866852
# for gene Vstm2l there is no coronal data.  Skipping
# for gene Pou6f2 coronal data has id 71249067
# for gene Tenm2 coronal data has id 79591631
# for gene Tmem163 coronal data has id 71670711
# for gene Hrh3 coronal data has id 73636034
# for gene S100a16 coronal data has id 77371787
# for gene Dpy19l1 coronal data has id 75042226
# for gene Amigo2 coronal data has id 71250310
# for gene Sh3bp4 coronal data has id 75774110
# for gene Bcl11b there is no coronal data.  Skipping
# for gene Fnbp1l coronal data has id 70560266
# for gene Crym coronal data has id 73592526
# for gene Gad2 coronal data has id 79591669
# for gene Ppp1r14c there is no coronal data.  Skipping
# for gene Pdgfd coronal data has id 1910
# for gene Ildr2 there is no coronal data.  Skipping
# for gene Peli2 there is no coronal data.  Skipping
# for gene Pou3f3 there is no coronal data.  Skipping
# for gene Ptprt coronal data has id 866
# for gene Manea coronal data has id 74882656
# for gene Gad1 coronal data has id 79556706
# for gene Arhgef3 there is no coronal data.  Skipping
# for gene Gpx3 coronal data has id 75080750
# for gene Fstl1 coronal data has id 71016596
# for gene Tbc1d9 coronal data has id 72079987
# for gene Vwc2 coronal data has id 77332096
# for gene Sema6a coronal data has id 71358651
# for gene Pam coronal data has id 73997147
# for gene Oas1e there is no coronal data.  Skipping
# for gene Il4ra coronal data has id 77413692
# for gene Flrt2 coronal data has id 73931417
# for gene Fam174b there is no coronal data.  Skipping
# for gene Akap13 coronal data has id 74581373
# for gene Pcdh17 coronal data has id 73636095
# for gene Car10 coronal data has id 71587832
# for gene Cxcl14 coronal data has id 74272041
# for gene Ephx1 there is no coronal data.  Skipping
# for gene Slc29a1 coronal data has id 1838
# for gene Slc5a5 there is no coronal data.  Skipping
# for gene Tspan5 coronal data has id 74657928
# for gene Ppp1r9a coronal data has id 71064176
# for gene Pcsk6 coronal data has id 75084491
# for gene Hspb1 coronal data has id 74363357
# for gene Qpct there is no coronal data.  Skipping
# for gene Akap7 there is no coronal data.  Skipping
# for gene Ajap1 coronal data has id 71717560
# for gene Wfdc12 there is no coronal data.  Skipping
# for gene Egfr there is no coronal data.  Skipping
# for gene Cadm1 there is no coronal data.  Skipping
# for gene Col25a1 coronal data has id 71924301
# for gene Fgfr1 coronal data has id 79588290
# for gene Pde5a coronal data has id 73931641
# for gene Mtmr6 coronal data has id 74658087
# for gene Gm7407 there is no coronal data.  Skipping
# for gene Zfp827 there is no coronal data.  Skipping
# for gene Lrrtm2 there is no coronal data.  Skipping
# for gene Wdr26 there is no coronal data.  Skipping
# for gene Rps6ka2 coronal data has id 70301276
# for gene Ankfy1 there is no coronal data.  Skipping
# for gene Pbx1 there is no coronal data.  Skipping
# for gene Dek there is no coronal data.  Skipping
# for gene Carf there is no coronal data.  Skipping
# for gene Pdcl3 there is no coronal data.  Skipping
# for gene Lsamp coronal data has id 625
# for gene Arl8b there is no coronal data.  Skipping
# for gene Cops3 there is no coronal data.  Skipping
# for gene Sil1 there is no coronal data.  Skipping
# for gene X1600012H06Rik there is no coronal data.  Skipping
# for gene Strn coronal data has id 73521824
# for gene Sox14 coronal data has id 73636036
# for gene Ephb1 coronal data has id 72077478
# for gene Gria4 coronal data has id 71358628
# for gene Cab39 there is no coronal data.  Skipping
# for gene Kcns1 there is no coronal data.  Skipping
# for gene Ngfr coronal data has id 79591691
# for gene Pgap1 there is no coronal data.  Skipping
# for gene Hspa1a there is no coronal data.  Skipping
# for gene Gna11 there is no coronal data.  Skipping
# for gene Rpl14 there is no coronal data.  Skipping
# for gene Satb2 coronal data has id 73992708
# for gene Trim28 coronal data has id 1071
# for gene Arsb there is no coronal data.  Skipping
# for gene Commd2 there is no coronal data.  Skipping
# for gene Ntrk2 coronal data has id 746
# for gene Crip1 there is no coronal data.  Skipping
# for gene Acbd3 there is no coronal data.  Skipping
# for gene Fxr2 there is no coronal data.  Skipping
# for gene Atp7a there is no coronal data.  Skipping
# for gene Kifap3 there is no coronal data.  Skipping
# for gene Prdx3 coronal data has id 70743842
# for gene Trappc4 there is no coronal data.  Skipping
# for gene Taok1 coronal data has id 74819235
# for gene Fxyd5 coronal data has id 74819694
# for gene Ngb coronal data has id 79556712
# for gene Pccb there is no coronal data.  Skipping
# for gene Nr3c1 coronal data has id 727
# for gene Adra1a coronal data has id 75042247
# for gene Hax1 coronal data has id 2303
# for gene Ube2q1 there is no coronal data.  Skipping
# for gene Marcks there is no coronal data.  Skipping
# for gene Vgf coronal data has id 71924165
# for gene Ifngr2 coronal data has id 1460
# for gene Arhgef40 there is no coronal data.  Skipping
# for gene Coq10b there is no coronal data.  Skipping
# for gene Rnpep there is no coronal data.  Skipping
# for gene Atp5j2 there is no coronal data.  Skipping
# for gene Chpf there is no coronal data.  Skipping
# for gene Stambpl1 there is no coronal data.  Skipping
# for gene X4933431E20Rik there is no coronal data.  Skipping
# for gene Rbms3 there is no coronal data.  Skipping
# for gene Ncdn coronal data has id 684
# for gene Cdh13 coronal data has id 77869863
# for gene Ube2ql1 coronal data has id 71249083
# for gene Dmxl2 there is no coronal data.  Skipping
# for gene Spen there is no coronal data.  Skipping
# for gene Olfr825 there is no coronal data.  Skipping
# for gene Pnmal2 there is no coronal data.  Skipping
# for gene Mapk3 coronal data has id 32576
# for gene Grk2 there is no coronal data.  Skipping
# for gene Cyfip2 there is no coronal data.  Skipping
# for gene Smchd1 there is no coronal data.  Skipping
# for gene Aldh1a3 there is no coronal data.  Skipping
# for gene Rasa3 there is no coronal data.  Skipping
# for gene Cadm2 coronal data has id 73635999
# for gene Stk39 there is no coronal data.  Skipping
# for gene A830010M20Rik there is no coronal data.  Skipping
# for gene Snrk there is no coronal data.  Skipping
# for gene Ap2m1 there is no coronal data.  Skipping
# for gene Cpne7 coronal data has id 73817432
# for gene Crocc there is no coronal data.  Skipping
# for gene Rab11a there is no coronal data.  Skipping
# for gene Gm42970 there is no coronal data.  Skipping
# for gene Tssc4 there is no coronal data.  Skipping
# for gene Gm43766 there is no coronal data.  Skipping
# for gene Pclo coronal data has id 71670682
# for gene Arrb2 there is no coronal data.  Skipping
# for gene Cdk15 there is no coronal data.  Skipping
# for gene Vsnl1 coronal data has id 1106
# for gene Prkacb coronal data has id 75043158
# for gene X4931406C07Rik there is no coronal data.  Skipping
# for gene Pcp4 coronal data has id 772
# for gene Ccnh there is no coronal data.  Skipping
# for gene Tab2 there is no coronal data.  Skipping
# for gene Timeless there is no coronal data.  Skipping
# for gene Ndufs5 there is no coronal data.  Skipping
# for gene Sdha there is no coronal data.  Skipping
# for gene Rb1 there is no coronal data.  Skipping
# for gene Atox1 there is no coronal data.  Skipping
# for gene Samd4b there is no coronal data.  Skipping
# for gene Ppp3ca coronal data has id 73817435
# for gene Pfdn1 there is no coronal data.  Skipping
# for gene Napb coronal data has id 75651234
# for gene Txndc9 there is no coronal data.  Skipping
# for gene Pik3r3 coronal data has id 74583163
# for gene Capn10 there is no coronal data.  Skipping
# for gene Gm43331 there is no coronal data.  Skipping
# for gene Tanc1 coronal data has id 72081515
# for gene Enah there is no coronal data.  Skipping
# for gene Zfp185 there is no coronal data.  Skipping
# for gene Gtf2a2 there is no coronal data.  Skipping
# for gene Kdm5c there is no coronal data.  Skipping
# for gene Ccz1 there is no coronal data.  Skipping
# for gene X9330158H04Rik there is no coronal data.  Skipping
# for gene Tyw1 there is no coronal data.  Skipping
# for gene Paics there is no coronal data.  Skipping
# for gene Ramp1 coronal data has id 1912
# for gene Camk2n1 there is no coronal data.  Skipping
# for gene Ddx1 there is no coronal data.  Skipping
# for gene Otud4 there is no coronal data.  Skipping
# for gene Tex9 there is no coronal data.  Skipping
# for gene Atp8a1 coronal data has id 74881560
# for gene Syt4 coronal data has id 2651
# for gene Chchd10 there is no coronal data.  Skipping
# for gene Nup85 there is no coronal data.  Skipping
# for gene Tor1b there is no coronal data.  Skipping
# for gene Raph1 there is no coronal data.  Skipping
# for gene Gm5141 there is no coronal data.  Skipping
# for gene Trp53rkb there is no coronal data.  Skipping
# for gene Rnasek coronal data has id 75934529
# for gene Dnaja4 coronal data has id 70744391
# for gene Atp5c1 there is no coronal data.  Skipping
# for gene Eefsec there is no coronal data.  Skipping
# for gene Cpe coronal data has id 1691
# for gene Fdft1 coronal data has id 75041432
# for gene Etl4 there is no coronal data.  Skipping
# for gene Tubb4a coronal data has id 1081
# for gene Auh there is no coronal data.  Skipping
# for gene Hmgcs1 coronal data has id 80517057
# for gene Pgm2l1 coronal data has id 70615597
# for gene Mtch1 there is no coronal data.  Skipping
# for gene Dusp7 there is no coronal data.  Skipping
# for gene Selenop there is no coronal data.  Skipping
# for gene Rnf168 there is no coronal data.  Skipping
# for gene Gm21596 there is no coronal data.  Skipping
# for gene BC051077 there is no coronal data.  Skipping
# for gene Gcm1 there is no coronal data.  Skipping
# for gene Olfr733 there is no coronal data.  Skipping
# for gene Mapkapk2 there is no coronal data.  Skipping
# for gene Cdadc1 there is no coronal data.  Skipping
# for gene Tbc1d14 coronal data has id 71020391
# for gene Ldhb there is no coronal data.  Skipping
# for gene Pecam1 there is no coronal data.  Skipping
# for gene Zfyve9 coronal data has id 73521827
# for gene Olfr1535 there is no coronal data.  Skipping
# for gene Smg6 there is no coronal data.  Skipping
# for gene Gm28439 there is no coronal data.  Skipping
# for gene Mdh1 there is no coronal data.  Skipping
# for gene Mc1r there is no coronal data.  Skipping
# for gene Vps54 there is no coronal data.  Skipping
# for gene Cope there is no coronal data.  Skipping
# for gene Dcbld2 coronal data has id 73992944
# for gene Mast1 there is no coronal data.  Skipping
# for gene Atp1b1 there is no coronal data.  Skipping
# for gene Cycs there is no coronal data.  Skipping
# for gene mt.Atp8 there is no coronal data.  Skipping
# for gene Gpd2 coronal data has id 70615598
# for gene Slc18a2 coronal data has id 79591703
# for gene Coa5 there is no coronal data.  Skipping
# for gene Snca coronal data has id 986
# for gene Sorbs2 there is no coronal data.  Skipping
# for gene Spock3 coronal data has id 70634298
# for gene Mocs2 there is no coronal data.  Skipping
# for gene Snrnp48 there is no coronal data.  Skipping
# for gene Olfm3 there is no coronal data.  Skipping
# for gene Col4a1 there is no coronal data.  Skipping
# for gene Wdr45 there is no coronal data.  Skipping
# for gene Cnn3 there is no coronal data.  Skipping
# for gene Morn2 there is no coronal data.  Skipping
# for gene Tenm1 there is no coronal data.  Skipping
# for gene Cep68 there is no coronal data.  Skipping
# for gene Slitrk5 there is no coronal data.  Skipping
# for gene Zhx3 there is no coronal data.  Skipping
# for gene Rab3c coronal data has id 73521805
# for gene Esr2 coronal data has id 71670737
# for gene Anks1b there is no coronal data.  Skipping
# for gene Kcnab1 coronal data has id 70301087
# for gene Adcy2 coronal data has id 79567501
# for gene Pbx3 coronal data has id 76085744
# for gene Utrn coronal data has id 73929872
# for gene Miat coronal data has id 72340194
# for gene Ap1s2 there is no coronal data.  Skipping
# for gene Tenm3 coronal data has id 79908833
# for gene Crtac1 coronal data has id 75749739
# for gene Crhr2 coronal data has id 79907934
# for gene Mgll coronal data has id 72129243
# for gene Pcdh11x coronal data has id 73521002
# for gene Pcdh15 there is no coronal data.  Skipping
# for gene Fgf9 there is no coronal data.  Skipping
# for gene Slit2 coronal data has id 980
# for gene Ntm coronal data has id 573
# for gene Slc17a8 coronal data has id 71587918

# %%
len(geneData)
# Out:
# 114

# %%
import zipfile
import os

for rNum in range(1,len(geneData)-1):
    row=geneData[rNum]
    id=str(row[6])
    print(rNum, ':', row[0], row[6])
    newName=''.join([id, '.zip'])
    build_string=''.join(['http://api.brain-map.org/',
                'grid_data/download/',
                id,
                '?include=energy'])
    
    req=requests.get(build_string, stream=True)
    req.raise_for_status()
    with open(newName, 'wb') as fd:
        for chunk in req.iter_content(chunk_size=50000):
            fd.write(chunk)
            
    geneZip=zipfile.ZipFile(newName)
    geneZip.extractall(None, ['energy.raw'])
    os.rename('energy.raw', ''.join(['e', id, '.raw']))
# Out:
# 1 : Asb4 71358591
# 2 : Prkcq 71670693
# 3 : St8sia2 77925023
# 4 : Trh 71016631
# 5 : Prph 70232000
# 6 : Fam19a2 73636033
# 7 : Clic1 67809267
# 8 : Fstl5 72283812
# 9 : Adra2a 73615550
# 10 : Slc6a1 476
# 11 : Tmem176b 77866852
# 12 : Pou6f2 71249067
# 13 : Tenm2 79591631
# 14 : Tmem163 71670711
# 15 : Hrh3 73636034
# 16 : S100a16 77371787
# 17 : Dpy19l1 75042226
# 18 : Amigo2 71250310
# 19 : Sh3bp4 75774110
# 20 : Fnbp1l 70560266
# 21 : Crym 73592526
# 22 : Gad2 79591669
# 23 : Pdgfd 1910
# 24 : Ptprt 866
# 25 : Manea 74882656
# 26 : Gad1 79556706
# 27 : Gpx3 75080750
# 28 : Fstl1 71016596
# 29 : Tbc1d9 72079987
# 30 : Vwc2 77332096
# 31 : Sema6a 71358651
# 32 : Pam 73997147
# 33 : Il4ra 77413692
# 34 : Flrt2 73931417
# 35 : Akap13 74581373
# 36 : Pcdh17 73636095
# 37 : Car10 71587832
# 38 : Cxcl14 74272041
# 39 : Slc29a1 1838
# 40 : Tspan5 74657928
# 41 : Ppp1r9a 71064176
# 42 : Pcsk6 75084491
# 43 : Hspb1 74363357
# 44 : Ajap1 71717560
# 45 : Col25a1 71924301
# 46 : Fgfr1 79588290
# 47 : Pde5a 73931641
# 48 : Mtmr6 74658087
# 49 : Rps6ka2 70301276
# 50 : Lsamp 625
# 51 : Strn 73521824
# 52 : Sox14 73636036
# 53 : Ephb1 72077478
# 54 : Gria4 71358628
# 55 : Ngfr 79591691
# 56 : Satb2 73992708
# 57 : Trim28 1071
# 58 : Ntrk2 746
# 59 : Prdx3 70743842
# 60 : Taok1 74819235
# 61 : Fxyd5 74819694
# 62 : Ngb 79556712
# 63 : Nr3c1 727
# 64 : Adra1a 75042247
# 65 : Hax1 2303
# 66 : Vgf 71924165
# 67 : Ifngr2 1460
# 68 : Ncdn 684
# 69 : Cdh13 77869863
# 70 : Ube2ql1 71249083
# 71 : Mapk3 32576
# 72 : Cadm2 73635999
# 73 : Cpne7 73817432
# 74 : Pclo 71670682
# 75 : Vsnl1 1106
# 76 : Prkacb 75043158
# 77 : Pcp4 772
# 78 : Ppp3ca 73817435
# 79 : Napb 75651234
# 80 : Pik3r3 74583163
# 81 : Tanc1 72081515
# 82 : Ramp1 1912
# 83 : Atp8a1 74881560
# 84 : Syt4 2651
# 85 : Rnasek 75934529
# 86 : Dnaja4 70744391
# 87 : Cpe 1691
# 88 : Fdft1 75041432
# 89 : Tubb4a 1081
# 90 : Hmgcs1 80517057
# 91 : Pgm2l1 70615597
# 92 : Tbc1d14 71020391
# 93 : Zfyve9 73521827
# 94 : Dcbld2 73992944
# 95 : Gpd2 70615598
# 96 : Slc18a2 79591703
# 97 : Snca 986
# 98 : Spock3 70634298
# 99 : Rab3c 73521805
# 100 : Esr2 71670737
# 101 : Kcnab1 70301087
# 102 : Adcy2 79567501
# 103 : Pbx3 76085744
# 104 : Utrn 73929872
# 105 : Miat 72340194
# 106 : Tenm3 79908833
# 107 : Crtac1 75749739
# 108 : Crhr2 79907934
# 109 : Mgll 72129243
# 110 : Pcdh11x 73521002
# 111 : Slit2 980
# 112 : Ntm 573

# %%
with open('lmOut.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    for rNum in range(1,len(geneData)-1):
        row=geneData[rNum]
        spamwriter.writerow(row)

# %%
print(id)
aaa=np.fromfile('e79591401.raw')
aaa.shape
sys.byteorder
# Out:
# 71924301
# 'little'

# %%
aaa.shape
# Out:
# (79663,)
